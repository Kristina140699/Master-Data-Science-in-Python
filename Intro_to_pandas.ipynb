# %% [markdown]
# <a href="https://colab.research.google.com/github/Kristina140699/Master-Data-Science-in-Python/blob/main/Intro_to_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas - Panel Data
# ### Pandas stands for Panel Data and is the core library for data manipulation and data analysis. It consists of single and multi-dimensional data structures for data-manipulation.
#
# Single-dimensional: Series Object. It is an one-dimensional labeled array.
#
# Multi-dimensional: Data-frame

# %%
import pandas as pd

# %%
s1 = pd.Series([1, 2, 3, 4, 5])
s1
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
type(s1)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## Changing the index

# %%
s1 = pd.Series([1,2,3,4,5], index = ['a', 'b', 'c', 'd', 'e'])
s1
# here we have got the series as a-e using index. Compare it with the prev example.
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
s1 = pd.Series([1,2,3,4,5], index = ['apple', 'boy', 'cat', 'dolphin', 'ear'])
s1
# Out:
# apple      1
# boy        2
# cat        3
# dolphin    4
# ear        5
# dtype: int64

# %% [markdown]
# ## Series Object from Dictionary

# %%
pd.Series({'a':10, 'b':20, 'c':30})
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %% [markdown]
# ## Chnaging index position

# %%
pd.Series({'a':10, 'b':20, 'c':30}, index=['b', 'c', 'd', 'a'])
# Out:
# b    20.0
# c    30.0
# d     NaN
# a    10.0
# dtype: float64

# %% [markdown]
# ## Extracting Individual Elements

# %%
# Extracting a single element
s1 = pd.Series([1,2,3,4,5,6,7,8,9])
s1[3]
# Out:
# 4

# %%
# Extracting elements from back
s1[-3:]
# Out:
# 6    7
# 7    8
# 8    9
# dtype: int64

# %%
s1[3:]
# Out:
# 3    4
# 4    5
# 5    6
# 6    7
# 7    8
# 8    9
# dtype: int64

# %%
# Extracting a sequence of elements
s1[:4]
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
s1[:-4]
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %% [markdown]
# ## Basic Math Operations on Series

# %%
s1+17
# Out:
# 0    18
# 1    19
# 2    20
# 3    21
# 4    22
# 5    23
# 6    24
# 7    25
# 8    26
# dtype: int64

# %%
s1 = pd.Series([1,2,3,4,5,6,7,8,9])
s2 = pd.Series([10, 20, 30, 40, 50, 60, 70, 80])

s1+s2
# Out:
# 0    11.0
# 1    22.0
# 2    33.0
# 3    44.0
# 4    55.0
# 5    66.0
# 6    77.0
# 7    88.0
# 8     NaN
# dtype: float64

# %%
s1-.9
# Out:
# 0    0.1
# 1    1.1
# 2    2.1
# 3    3.1
# 4    4.1
# 5    5.1
# 6    6.1
# 7    7.1
# 8    8.1
# dtype: float64

# %%
s2-s1
# Out:
# 0     9.0
# 1    18.0
# 2    27.0
# 3    36.0
# 4    45.0
# 5    54.0
# 6    63.0
# 7    72.0
# 8     NaN
# dtype: float64

# %%
s1*2
# Out:
# 0     2
# 1     4
# 2     6
# 3     8
# 4    10
# 5    12
# 6    14
# 7    16
# 8    18
# dtype: int64

# %% [markdown]
# # Pandas Dataframe
# ## Dataframe is a 2-dimensional labelled data-structure. A data-frame comprises of rows and columns.

# %%
import pandas as pd
pd.DataFrame({"Name":['Bob', 'Sam', 'Anne'], "Marks":[76, 88, 92]})
# Out:
#    Name  Marks
# 0   Bob     76
# 1   Sam     88
# 2  Anne     92

# %% [markdown]
# ## Dataframe In-Built Functions
#
# 1. head()
# 2. describe()
# 3. tail()
# 4. shape()

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Reading the data frame
iris = pd.read_csv('/content/drive/MyDrive/Projects/IRIS.csv')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
iris.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# Extracting individual rows and columns from a dataframe
# help us to extract rows and columns w.r.t index. The 'i' in iloc stands for index.
iris.iloc[0:5, 0:3]
# Out:
#    sepal_length  sepal_width  petal_length
# 0           5.1          3.5           1.4
# 1           4.9          3.0           1.4
# 2           4.7          3.2           1.3
# 3           4.6          3.1           1.5
# 4           5.0          3.6           1.4

# %%
# Here we can't give the index values rather we can give the column names. Else we'll get error!
iris.loc[0:15, ("sepal_length", "petal_length")]
# Out:
#     sepal_length  petal_length
# 0            5.1           1.4
# 1            4.9           1.4
# 2            4.7           1.3
# 3            4.6           1.5
# 4            5.0           1.4
# 5            5.4           1.7
# 6            4.6           1.4
# 7            5.0           1.5
# 8            4.4           1.4
# 9            4.9           1.5
# 10           5.4           1.5
# 11           4.8           1.6
# 12           4.8           1.4
# 13           4.3           1.1
# 14           5.8           1.2
# 15           5.7           1.5

# %% [markdown]
# ## Dropping the Columns

# %%
new_iris = iris.drop('sepal_length', axis=1) #axis 1 means dropping a column.
new_iris
# Out:
#      sepal_width  petal_length  petal_width         species
# 0            3.5           1.4          0.2     Iris-setosa
# 1            3.0           1.4          0.2     Iris-setosa
# 2            3.2           1.3          0.2     Iris-setosa
# 3            3.1           1.5          0.2     Iris-setosa
# 4            3.6           1.4          0.2     Iris-setosa
# ..           ...           ...          ...             ...
# 145          3.0           5.2          2.3  Iris-virginica
# 146          2.5           5.0          1.9  Iris-virginica
# 147          3.0           5.2          2.0  Iris-virginica
# 148          3.4           5.4          2.3  Iris-virginica
# 149          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 4 columns]

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris.drop([1,2,3, 4,5, 6], axis = 0) # axis=0 means we are dropping a row.
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 7             5.0          3.4           1.5          0.2     Iris-setosa
# 8             4.4          2.9           1.4          0.2     Iris-setosa
# 9             4.9          3.1           1.5          0.1     Iris-setosa
# 10            5.4          3.7           1.5          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [144 rows x 5 columns]

# %% [markdown]
# ## Pandas Functions
#
# 1. Mean
# 2. Median
# 3. Minimum
# 4. Maximum

# %%
iris.mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# ...

# %%
iris.median
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.median of      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# ...

# %%
iris.min()
# Out:
# sepal_length            4.3
# sepal_width             2.0
# petal_length            1.0
# petal_width             0.1
# species         Iris-setosa
# dtype: object

# %%
iris.max()
# Out:
# sepal_length               7.9
# sepal_width                4.4
# petal_length               6.9
# petal_width                2.5
# species         Iris-virginica
# dtype: object

# %% [markdown]
# ## Apply() method
# Apply method works on different columns. If we want to perform the same function on different columns of a pandas dataframe and use apply. But we need to have a function with we can apply across the different columns.

# %%
iris[['sepal_length', 'petal_length']]
# Out:
#      sepal_length  petal_length
# 0             5.1           1.4
# 1             4.9           1.4
# 2             4.7           1.3
# 3             4.6           1.5
# 4             5.0           1.4
# ..            ...           ...
# 145           6.7           5.2
# 146           6.3           5.0
# 147           6.5           5.2
# 148           6.2           5.4
# 149           5.9           5.1
#
# [150 rows x 2 columns]

# %%
def half(val):
  return val/2

# %%
iris[['sepal_length', 'petal_length']].apply(half)
# Out:
#      sepal_length  petal_length
# 0            2.55          0.70
# 1            2.45          0.70
# 2            2.35          0.65
# 3            2.30          0.75
# 4            2.50          0.70
# ..            ...           ...
# 145          3.35          2.60
# 146          3.15          2.50
# 147          3.25          2.60
# 148          3.10          2.70
# 149          2.95          2.55
#
# [150 rows x 2 columns]

# %%
iris[['sepal_width', 'petal_width']]
# Out:
#      sepal_width  petal_width
# 0            3.5          0.2
# 1            3.0          0.2
# 2            3.2          0.2
# 3            3.1          0.2
# 4            3.6          0.2
# ..           ...          ...
# 145          3.0          2.3
# 146          2.5          1.9
# 147          3.0          2.0
# 148          3.4          2.3
# 149          3.0          1.8
#
# [150 rows x 2 columns]

# %%
def double(val):
  return val*2

# %%
iris[['sepal_width', 'petal_width']].apply(double)
# Out:
#      sepal_width  petal_width
# 0            7.0          0.4
# 1            6.0          0.4
# 2            6.4          0.4
# 3            6.2          0.4
# 4            7.2          0.4
# ..           ...          ...
# 145          6.0          4.6
# 146          5.0          3.8
# 147          6.0          4.0
# 148          6.8          4.6
# 149          6.0          3.6
#
# [150 rows x 2 columns]

# %% [markdown]
# ## value_counts()
#
# ## sort_values()

# %%
iris['species'].value_counts()
# Out:
# species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
iris.sort_values(by = 'sepal_length')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 13            4.3          3.0           1.1          0.1     Iris-setosa
# 42            4.4          3.2           1.3          0.2     Iris-setosa
# 38            4.4          3.0           1.3          0.2     Iris-setosa
# 8             4.4          2.9           1.4          0.2     Iris-setosa
# 41            4.5          2.3           1.3          0.3     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 122           7.7          2.8           6.7          2.0  Iris-virginica
# 118           7.7          2.6           6.9          2.3  Iris-virginica
# 117           7.7          3.8           6.7          2.2  Iris-virginica
# 135           7.7          3.0           6.1          2.3  Iris-virginica
# 131           7.9          3.8           6.4          2.0  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Combining Data Frames

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Reading the data frame
emp_data = pd.read_csv('/content/drive/MyDrive/Projects/emp.csv')
emp_data.head(20)
# Out:
#     Unnamed: 0    emp_id  age        Dept location education  \
# 0            0    HR8270   28          HR   Suburb        PG
# 1            1  TECH1860   50  Technology   Suburb        PG
# 2            2  TECH6390   43  Technology   Suburb        UG
# 3            3   SAL6191   44       Sales     City        PG
# 4            4    HR6734   33          HR     City        UG
# 5            5   PUR7265   40  Purchasing   Suburb        UG
# 6            6   PUR1466   26  Purchasing   Suburb        UG
# 7            7  TECH5426   25  Technology     City        UG
# 8            8    HR6578   35          HR     City        PG
# 9            9  TECH9322   45  Technology     City        PG
# 10          10   MKT2685   31   Marketing     City        UG
# 11          11  TECH1769   43  Technology   Suburb        PG
# 12          12  TECH7949   28  Technology     City        UG
# 13          13   PUR3433   48  Purchasing   Suburb        PG
# ...

# %%
df1 = pd.DataFrame({
  "emp_id":['TECH1860', 'TECH6390', 'SAL6191', 'HR6734'],
  "Dept":['HR','Technology', 'Technology', 'Sales'],
  "education":['PG', 'PG', 'UG', 'PG'],
  'salary':[86750, 42419, 65715, 29805]
}, index=[0,1,2,3])

df1
# Out:
#      emp_id        Dept education  salary
# 0  TECH1860          HR        PG   86750
# 1  TECH6390  Technology        PG   42419
# 2   SAL6191  Technology        UG   65715
# 3    HR6734       Sales        PG   29805

# %%
df2 = pd.DataFrame({
  "emp_id":['TECH1860', 'TECH6390', 'SAL6191', 'HR6734'],
  "location":['Suburb','Suburb', 'City', 'City'],
  "job_level":[5, 3, 4, 2],
  'salary':[86750, 42419, 65715, 29805]
}, index=[0,1,2,3])

df2
# Out:
#      emp_id location  job_level  salary
# 0  TECH1860   Suburb          5   86750
# 1  TECH6390   Suburb          3   42419
# 2   SAL6191     City          4   65715
# 3    HR6734     City          2   29805

# %%
pd.concat([df1, df2], axis=0, sort=False)
# Out:
#      emp_id        Dept education  salary location  job_level
# 0  TECH1860          HR        PG   86750      NaN        NaN
# 1  TECH6390  Technology        PG   42419      NaN        NaN
# 2   SAL6191  Technology        UG   65715      NaN        NaN
# 3    HR6734       Sales        PG   29805      NaN        NaN
# 0  TECH1860         NaN       NaN   86750   Suburb        5.0
# 1  TECH6390         NaN       NaN   42419   Suburb        3.0
# 2   SAL6191         NaN       NaN   65715     City        4.0
# 3    HR6734         NaN       NaN   29805     City        2.0

# %%
pd.concat([df1, df2], axis=0, sort=True)
# Out:
#          Dept education    emp_id  job_level location  salary
# 0          HR        PG  TECH1860        NaN      NaN   86750
# 1  Technology        PG  TECH6390        NaN      NaN   42419
# 2  Technology        UG   SAL6191        NaN      NaN   65715
# 3       Sales        PG    HR6734        NaN      NaN   29805
# 0         NaN       NaN  TECH1860        5.0   Suburb   86750
# 1         NaN       NaN  TECH6390        3.0   Suburb   42419
# 2         NaN       NaN   SAL6191        4.0     City   65715
# 3         NaN       NaN    HR6734        2.0     City   29805

# %%
pd.concat([df1, df2], axis=1, sort=False) #concatinated across the columns
# Out:
#      emp_id        Dept education  salary    emp_id location  job_level  \
# 0  TECH1860          HR        PG   86750  TECH1860   Suburb          5
# 1  TECH6390  Technology        PG   42419  TECH6390   Suburb          3
# 2   SAL6191  Technology        UG   65715   SAL6191     City          4
# 3    HR6734       Sales        PG   29805    HR6734     City          2
#
#    salary
# 0   86750
# 1   42419
# 2   65715
# 3   29805

# %% [markdown]
# ## Inner Join

# %%
pd.merge(df1, df2, how='inner', on='emp_id')
 #returns only the data the are common between the two tables.
# Out:
#      emp_id        Dept education  salary_x location  job_level  salary_y
# 0  TECH1860          HR        PG     86750   Suburb          5     86750
# 1  TECH6390  Technology        PG     42419   Suburb          3     42419
# 2   SAL6191  Technology        UG     65715     City          4     65715
# 3    HR6734       Sales        PG     29805     City          2     29805

# %% [markdown]
# ## Left Join

# %%
pd.merge(df1, df2, how='left', on='emp_id')
# Out:
#      emp_id        Dept education  salary_x location  job_level  salary_y
# 0  TECH1860          HR        PG     86750   Suburb          5     86750
# 1  TECH6390  Technology        PG     42419   Suburb          3     42419
# 2   SAL6191  Technology        UG     65715     City          4     65715
# 3    HR6734       Sales        PG     29805     City          2     29805

# %% [markdown]
# ## Right Join

# %%
pd.merge(df1, df2, how='right', on='emp_id')
# Out:
#      emp_id        Dept education  salary_x location  job_level  salary_y
# 0  TECH1860          HR        PG     86750   Suburb          5     86750
# 1  TECH6390  Technology        PG     42419   Suburb          3     42419
# 2   SAL6191  Technology        UG     65715     City          4     65715
# 3    HR6734       Sales        PG     29805     City          2     29805

# %% [markdown]
# ## Outer Join

# %%
pd.merge(df1, df2, how='outer', on='emp_id')
# Out:
#      emp_id        Dept education  salary_x location  job_level  salary_y
# 0  TECH1860          HR        PG     86750   Suburb          5     86750
# 1  TECH6390  Technology        PG     42419   Suburb          3     42419
# 2   SAL6191  Technology        UG     65715     City          4     65715
# 3    HR6734       Sales        PG     29805     City          2     29805
